# %% [markdown]
# <a href="https://colab.research.google.com/github/avxsharma-glitch/python-scratch/blob/main/income_tax_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
income = float(input("Enter the income"))
if income >= 10000 and income < 50000:
   print("Income tax is 5% ")
elif income >= 50000 and income < 100000:
   print("Income tax is 10% ")
elif income >= 100000 and income < 200000:
   print("Income tax is 20% ")
else:
   print("Income tax calculation for other incomes.")
# Out:
# Enter the income15000
# Income tax is 5%

# %%
A = 0
for B in [1, 2]:
    A = A + 1
print(A)
# Out:
# 2

# %%
A = 0
for B in [1, 2, 3]:
    A = B
print(A)
# Out:
# 3

# %%
def swap(a, b):
    print("Before swapping: A =", a, "and B =", b)

    # Using temporary variable
    temp = a
    a = b
    b = temp

    print("After swapping: A =", a, "and B =", b)
    return a, b
    print(swap(1, 2))
