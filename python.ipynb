# %% [markdown]
# <a href="https://colab.research.google.com/github/avxsharma-glitch/python-scratch/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I am starting  python programing from the scratch # 1st program

# %%
print("Hii I am Avx") and (" It is my first program ")
# Out:
# Hii I am Avx

# %% [markdown]
# Comments, Escape Sequences & Print Statement

# %%
# comment ( ctrl + /)
print("hey i am \"avx\" \n and i am reading it ")
#print( objects(s), sep=seprator,end = end , file = file , flush= flush  )
print(" hello",4,5 ,sep="-",end="007\n")
print("Avx")
# Out:
# hey i am "avx"
#  and i am reading it
#  hello-4-5007
# Avx

# %% [markdown]
# Variable and Data types

# %%
# numeric(float,int, complex) , text(str) , boolean , sequenced data(list, tuple ) , mapped data - dict
a = 1.1
print(a)
b = "avx"
print(b)
print(a+55)
c = True
d = None
e = complex( 4 , 5 )

list1 =  8,2.3, [4.5,2] , "apple","banana"
print(list1)

print("Type of a is ", type((a)))
print("Type of a is ", type((b)))
print("Type of a is ", type((c)))
print("Type of a is ", type((d)))
print("Type of a is ", type((e)))
# Out:
# 1.1
# avx
# 56.1
# (8, 2.3, [4.5, 2], 'apple', 'banana')
# Type of a is  <class 'float'>
# Type of a is  <class 'str'>
# Type of a is  <class 'bool'>
# Type of a is  <class 'NoneType'>
# Type of a is  <class 'complex'>

# %% [markdown]
# Operators

# %%
print(6+3)# addition +
print(6-3)# substation -
print(6*3)# multiplication *
print(6/3)#division
print(6**3)# exponential **
print(6//3)# floor division //
print(6%3)# modulus %
# Out:
# 9
# 3
# 18
# 2.0
# 216
# 2
# 0

# %% [markdown]
# Exercise 1: Calculator using Python

# %%
a = input("First number" )
b = input("Second Number")
